# %% [markdown]
# # 🎉 Conda 가상환경 설정 완료!
#
# 현재 `live_ai` 가상환경 설정이 성공적으로 완료되었습니다.
#
# 오른쪽 상단의 **`Select Kernel`** (또는 커널 선택) 버튼을 클릭한 후, **`Python 3.11 (live_ai)`**를 선택해서 아래 코드를 실행해보세요!

# %%
import sys
print(f"현재 사용 중인 파이썬 위치: {sys.executable}")
print("정상적으로 작동합니다! 🔥")
